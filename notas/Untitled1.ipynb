# %%
import pandas as pd
csv = pd.read_csv('../data/HomeCredit_columns_description.csv', encoding = 'latin-1', index_col= 1,)

# %%
print(csv.loc['application_{train|test}.csv', :])
# Out:
#                               Unnamed: 0                         Row  \
# Table
# application_{train|test}.csv           1                  SK_ID_CURR
# application_{train|test}.csv           2                      TARGET
# application_{train|test}.csv           5          NAME_CONTRACT_TYPE
# application_{train|test}.csv           6                 CODE_GENDER
# application_{train|test}.csv           7                FLAG_OWN_CAR
# application_{train|test}.csv           8             FLAG_OWN_REALTY
# application_{train|test}.csv           9                CNT_CHILDREN
# application_{train|test}.csv          10            AMT_INCOME_TOTAL
# application_{train|test}.csv          11                  AMT_CREDIT
# application_{train|test}.csv          12                 AMT_ANNUITY
# application_{train|test}.csv          13             AMT_GOODS_PRICE
# application_{train|test}.csv          14             NAME_TYPE_SUITE
# ...

# %%
csv = pd.read_csv('../data/.csv', encoding = 'latin-1', index_col= 1,)
