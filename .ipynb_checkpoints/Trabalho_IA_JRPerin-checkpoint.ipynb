# %% [markdown]
# # Trabalho de Inteligência Artificial I

# %% [markdown]
# ### __Prof:__ Hitoshi Nagano, Ph.D.
#
# ### __Aluno:__ João Roberto Perin

# %% [markdown]
# #### Referências utilizadas como apoio:
#
# > [Pandas Dataframe by Example](http://queirozf.com/entries/pandas-dataframe-by-example)
# > [Statsmodels Examples](https://www.statsmodels.org/stable/examples/index.html#regression)
# > [OLS](https://www.statsmodels.org/dev/examples/notebooks/generated/ols.html)
# > [Linear Mixed Effects Models](https://www.statsmodels.org/stable/examples/notebooks/generated/mixed_lm_example.html)
# > [28 useful Pandas functions you might not know](https://paulovasconcellos.com.br/28-useful-pandas-functions-you-might-not-know-de42c59db085)
# > [Decision Tree com Sklearn parte 2: Regressões e alguns plots](https://juliocprocha.wordpress.com/2017/05/01/decision-tree-com-sklearn-parte-2-regressoes-e-alguns-plots/)
# > [Your First Machine Learning Project in Python Step-By-Step](https://machinelearningmastery.com/machine-learning-in-python-step-by-step/)
# > [Exploring Titanic Dataset using pandas](http://www.awesomestats.in/python-pandas-titanic/)
#
#
# #### Notas para complementar o trabalho posteriormente:
#
# [Evaluating model performances in Python using resampling](http://www.fabienplisson.com/cross-validation-classifiers/)
# * Professor comentou que há desbalanceamento entre Target = 1 e Target = 0.
# * Existem métodos melhores do que **accuracy_score** para validar a performance do modelo

# %% [markdown]
# # <font color='#b94646'> Instruções: </font>

# %% [markdown]
# 1) __Baixar os datasets em:__  https://www.kaggle.com/c/home-credit-default-risk/data
#
# 2) __Explorar conforme instruções:__
#
#  * __application_train.csv:__ Esse csv possui 122 colunas: explorar 40 colunas sendo as primeiras 30 obrigatórias e 10 adicionais a escolher.
#
#  * 30 colunas obrigatórias:
#
# >  SK_ID_CURR
# >  TARGET
# >  NAME_CONTRACT_TYPE
# >  CODE_GENDER
# >  FLAG_OWN_CAR
# >  FLAG_OWN_REALTY
# >  CNT_CHILDREN
# >  AMT_INCOME_TOTAL
# >  AMT_CREDIT
# >  AMT_ANNUITY
# >  AMT_GOODS_PRICE
# >  NAME_TYPE_SUITE
# >  NAME_INCOME_TYPE
# >  NAME_EDUCATION_TYPE
# >  NAME_FAMILY_STATUS
# >  NAME_HOUSING_TYPE
# >  REGION_POPULATION_RELATIVE
# >  DAYS_BIRTH
# >  DAYS_EMPLOYED
# >  DAYS_REGISTRATION
# >  DAYS_ID_PUBLISH
# >  OWN_CAR_AGE
# >  FLAG_MOBIL
# >  FLAG_EMP_PHONE
# >  FLAG_WORK_PHONE
# >  FLAG_CONT_MOBILE
# >  FLAG_PHONE
# >  FLAG_EMAIL
# >  OCCUPATION_TYPE
# >  CNT_FAM_MEMBERS
#
#  * alunos deverão se organizar para que todas as colunas sejam exploradas
#  * escolher dois arquivos, para exploração e join/merge/concat com o 'application_train.csv'
#
# >  HomeCredit_columns_description.csv
# >  POS_CASH_balance.csv
# >  credit_card_balance.csv
# >  installments_payments.csv
# >  application_train.csv
# >  bureau.csv
# >  previous_application.csv
# >  bureau_balance.csv
# >  sample_submission.csv
#
# 3) __objetivos:__
# * entendimento do problema de negócio
# * carregamento do dataset
# * identificação e tratamento de NaN
# * exploração univariada, bivariada
# * visualizações
# * insights de negócio
# * formatação do dataset para algoritmos de machine learning
# * criação de features: agregação de dados, junção de dois ou mais dataframes
#
# 4) __entregável:__ jupyter notebook. Não será necessário apresentação em powerpoint, nem relatório.
#
# 5) __entrega limite:__ 10/agosto/2018 - 23:59h
#
# 6) __trabalho individual.__ Haverá aplicação sistema anti-plágio nas submissões. (http://www.fgv.br/mailing/codigo-etica-conduta/24/)
#    suspeitas de plágio estarão sujeitos a arguição oral de 5 mins por aluno no ultimo dia de aula (11/agosto/2018),
#
# 7) __avaliação:__
# * jupyter notebook e arguição (se houver)

# %% [markdown]
# # <font color='#b94646'>Definição dos dados de trabalho </font>

# %% [markdown]
# ## Configurações

# %%
import pandas as pd

semente = 2306 # <-- Data de aniversário


df = pd.read_csv('./data/application_train.csv')

# Pegando as 30 colunas obrigatórias
df30 = df.iloc[:,0:30]

# Pegando colunas a partir da 31 (30 pq é indice 0) para sorteio
df_temp=df.iloc[:,30:]

# Sorteio de 10 colunas com a semente Data Aniversario
df10 = df_temp.sample(10,axis=1,random_state=semente)

# Juntar todas as colunas 30 obrigatorias + 10 do sorteio
df40 = pd.concat([df30, df10], axis=1)

# Imprimir o resultado:
i = 1
for x in df40.columns:
    print(str(i) + " - " + x)
    i += 1
# Out:
# 1 - SK_ID_CURR
# 2 - TARGET
# 3 - NAME_CONTRACT_TYPE
# 4 - CODE_GENDER
# 5 - FLAG_OWN_CAR
# 6 - FLAG_OWN_REALTY
# 7 - CNT_CHILDREN
# 8 - AMT_INCOME_TOTAL
# 9 - AMT_CREDIT
# 10 - AMT_ANNUITY
# 11 - AMT_GOODS_PRICE
# 12 - NAME_TYPE_SUITE
# 13 - NAME_INCOME_TYPE
# 14 - NAME_EDUCATION_TYPE
# 15 - NAME_FAMILY_STATUS
# 16 - NAME_HOUSING_TYPE
# 17 - REGION_POPULATION_RELATIVE
# 18 - DAYS_BIRTH
# 19 - DAYS_EMPLOYED
# 20 - DAYS_REGISTRATION
# 21 - DAYS_ID_PUBLISH
# 22 - OWN_CAR_AGE
# 23 - FLAG_MOBIL
# 24 - FLAG_EMP_PHONE
# 25 - FLAG_WORK_PHONE
# 26 - FLAG_CONT_MOBILE
# 27 - FLAG_PHONE
# 28 - FLAG_EMAIL
# 29 - OCCUPATION_TYPE
# 30 - CNT_FAM_MEMBERS
# 31 - DEF_30_CNT_SOCIAL_CIRCLE
# 32 - FLAG_DOCUMENT_8
# 33 - FLAG_DOCUMENT_3
# 34 - FLAG_DOCUMENT_15
# 35 - LIVINGAREA_MEDI
# 36 - EMERGENCYSTATE_MODE
# 37 - REGION_RATING_CLIENT_W_CITY
# 38 - FLOORSMIN_AVG
# 39 - FLAG_DOCUMENT_19
# 40 - ORGANIZATION_TYPE

# %%
# %matplotlib inline

from __future__ import print_function

import numpy  as np
import pandas as pd
import seaborn as sns

pd.set_option('display.precision', 2)
pd.set_eng_float_format(accuracy=3, use_eng_prefix=True)

import matplotlib.pyplot as plt
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# Machine Learn
#-------------------------------------------

# Transforma os dados em categoricos
from sklearn.preprocessing import LabelEncoder

# Classifica os dados
from sklearn.ensemble import RandomForestClassifier

# Valida o resultado do modelo
from sklearn.metrics import accuracy_score

# Faz a divisão entre Treino e Teste
from sklearn.model_selection import train_test_split

# Regressao Linear
import statsmodels.api as sm
import statsmodels.formula.api as smf


plot_style = 'seaborn'

# %% [markdown]
# # Carga dos Dados

# %%
df = df40.copy(deep=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 40 columns):
# SK_ID_CURR                     307511 non-null int64
# TARGET                         307511 non-null int64
# NAME_CONTRACT_TYPE             307511 non-null object
# CODE_GENDER                    307511 non-null object
# FLAG_OWN_CAR                   307511 non-null object
# FLAG_OWN_REALTY                307511 non-null object
# CNT_CHILDREN                   307511 non-null int64
# AMT_INCOME_TOTAL               307511 non-null float64
# AMT_CREDIT                     307511 non-null float64
# AMT_ANNUITY                    307499 non-null float64
# AMT_GOODS_PRICE                307233 non-null float64
# NAME_TYPE_SUITE                306219 non-null object
# NAME_INCOME_TYPE               307511 non-null object
# NAME_EDUCATION_TYPE            307511 non-null object
# NAME_FAMILY_STATUS             307511 non-null object
# ...

# %%
# Configurando o índice
df.set_index('SK_ID_CURR', inplace = True);

# %%
df.shape
# Out:
# (307511, 39)

# %% [markdown]
# # Separando as colunas por tipo de tratamento

# %%
# Colunas Categóricas:
categoricas = df.select_dtypes(exclude=['int', 'float']).columns

# %%
# Colunas Não Categóricas
nao_categoricas = df.select_dtypes(exclude=['object']).columns

# %%
# Colunas com Missing Values
missing = df.columns[df.isnull().any()]

# %%
# Colunas sem Missing Values
nao_missing = df.columns[~df.isnull().any()]

# %% [markdown]
# ### - Colunas categóricas

# %%
categoricas
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'OCCUPATION_TYPE',
#        'EMERGENCYSTATE_MODE', 'ORGANIZATION_TYPE'],
#       dtype='object')

# %% [markdown]
# ### - Colunas não categóricas

# %%
nao_categoricas
# Out:
# Index(['TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
#        'OWN_CAR_AGE', 'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE',
#        'FLAG_CONT_MOBILE', 'FLAG_PHONE', 'FLAG_EMAIL', 'CNT_FAM_MEMBERS',
#        'DEF_30_CNT_SOCIAL_CIRCLE', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_3',
#        'FLAG_DOCUMENT_15', 'LIVINGAREA_MEDI', 'REGION_RATING_CLIENT_W_CITY',
#        'FLOORSMIN_AVG', 'FLAG_DOCUMENT_19'],
#       dtype='object')

# %% [markdown]
# ### - Colunas sem missing values

# %%
nao_missing
# Out:
# Index(['TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
#        'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_MOBIL',
#        'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_3', 'FLAG_DOCUMENT_15',
#        'REGION_RATING_CLIENT_W_CITY', 'FLAG_DOCUMENT_19', 'ORGANIZATION_TYPE'],
#       dtype='object')

# %% [markdown]
# ### - Colunas com missing values

# %%
missing
# Out:
# Index(['AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'OWN_CAR_AGE',
#        'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'LIVINGAREA_MEDI', 'EMERGENCYSTATE_MODE', 'FLOORSMIN_AVG'],
#       dtype='object')

# %% [markdown]
# #
#
# # Entendendo a Variável Target
#
# **Obs.:** Esse trecho não estava no material entrege

# %%
targetcount = df['TARGET'].value_counts().sort_values()
targetcount
# Out:
# 1     24825
# 0    282686
# Name: TARGET, dtype: int64

# %% [markdown]
# ### Percentual  de 0 = Clientes em dia com o pagamento

# %%
print ('Percentual de 0 = ' + str(round((targetcount[0] / (targetcount[0] + targetcount[1]) * 100), 2)))
# Out:
# Percentual de 0 = 91.93

# %% [markdown]
# ### Percentual de 1 = Clientes com problemas no pagamento

# %%
print ('Percentual de 1 = ' + str(round((targetcount[1] / (targetcount[0] + targetcount[1]) * 100), 2)))
# Out:
# Percentual de 1 = 8.07

# %% [markdown]
# <font color='red'>
# ## Há desbalanceamento grave da variável ==> 91,93% vs 8,07%
# </font>
# **Obs.:** Fim do trecho que não estava

# %% [markdown]
# #
#
# # Análise Univariada dos Dados

# %% [markdown]
# ## Variáveis Categóricas

# %%
# Explorando as variáveis categóricas:

for x in df[categoricas]:
    line = 50 * '-'
    print (x)
    print (line)
    print (df[x].value_counts( dropna=False ))
    print (line)
    print ()
# Out:
# NAME_CONTRACT_TYPE
# --------------------------------------------------
# Cash loans         278232
# Revolving loans     29279
# Name: NAME_CONTRACT_TYPE, dtype: int64
# --------------------------------------------------
#
# CODE_GENDER
# --------------------------------------------------
# F      202448
# M      105059
# XNA         4
# Name: CODE_GENDER, dtype: int64
# --------------------------------------------------
#
# FLAG_OWN_CAR
# --------------------------------------------------
# N    202924
# Y    104587
# Name: FLAG_OWN_CAR, dtype: int64
# --------------------------------------------------
#
# FLAG_OWN_REALTY
# --------------------------------------------------
# Y    213312
# N     94199
# Name: FLAG_OWN_REALTY, dtype: int64
# --------------------------------------------------
#
# NAME_TYPE_SUITE
# --------------------------------------------------
# Unaccompanied      248526
# Family              40149
# Spouse, partner     11370
# Children             3267
# ...

# %% [markdown]
# ## Variáveis Não Categóricas

# %%
for x in df[nao_categoricas[2:]]:
    line = 50 * '-'
    print (x)
    print (line)
    print(df[x].describe())
    print (line)
    print ()
# Out:
# AMT_INCOME_TOTAL
# --------------------------------------------------
# count    307.511k
# mean     168.798k
# std      237.123k
# min       25.650k
# 25%      112.500k
# 50%      147.150k
# 75%      202.500k
# max      117.000M
# Name: AMT_INCOME_TOTAL, dtype: float64
# --------------------------------------------------
#
# AMT_CREDIT
# --------------------------------------------------
# count    307.511k
# mean     599.026k
# std      402.491k
# min       45.000k
# 25%      270.000k
# 50%      513.531k
# 75%      808.650k
# max        4.050M
# Name: AMT_CREDIT, dtype: float64
# --------------------------------------------------
#
# AMT_ANNUITY
# --------------------------------------------------
# count    307.499k
# mean      27.109k
# std       14.494k
# min        1.616k
# 25%       16.524k
# 50%       24.903k
# 75%       34.596k
# max      258.026k
# Name: AMT_ANNUITY, dtype: float64
# --------------------------------------------------
#
# AMT_GOODS_PRICE
# ...

# %% [markdown]
# ## Pela análise, vemos que tem algumas variáveis que poderiam ser Categóricas:

# %% [markdown]
# FLAG_MOBIL
# FLAG_EMP_PHONE
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# FLAG_DOCUMENT_8
# FLAG_DOCUMENT_3
# FLAG_DOCUMENT_15
# FLAG_DOCUMENT_19

# %%
# Vou convertê-las em Variáveis Categóricas:
to_convert = [
    'FLAG_MOBIL',
    'FLAG_EMP_PHONE', 
    'FLAG_WORK_PHONE', 
    'FLAG_CONT_MOBILE',
    'FLAG_PHONE',
    'FLAG_EMAIL',
    'FLAG_DOCUMENT_8',
    'FLAG_DOCUMENT_3',
    'FLAG_DOCUMENT_15',
    'FLAG_DOCUMENT_19',
]

# %%
# Convertendo os 1/0 em Y/N:

# Pega todas as linhas que estão nas colunas "to_convert"
#bkp = df.loc[ : , to_convert]

for x in to_convert:
    df[x] = df[x].replace({0 : 'N', 1: 'Y'}, inplace=False)
    df[x] = df[x].astype(object)

# %%
for x in to_convert:
    print (40 * "-")
    print (df[x].value_counts())
# Out:
# ----------------------------------------
# Y    307510
# N         1
# Name: FLAG_MOBIL, dtype: int64
# ----------------------------------------
# Y    252125
# N     55386
# Name: FLAG_EMP_PHONE, dtype: int64
# ----------------------------------------
# N    246203
# Y     61308
# Name: FLAG_WORK_PHONE, dtype: int64
# ----------------------------------------
# Y    306937
# N       574
# Name: FLAG_CONT_MOBILE, dtype: int64
# ----------------------------------------
# N    221080
# Y     86431
# Name: FLAG_PHONE, dtype: int64
# ----------------------------------------
# N    290069
# Y     17442
# Name: FLAG_EMAIL, dtype: int64
# ----------------------------------------
# N    282487
# Y     25024
# Name: FLAG_DOCUMENT_8, dtype: int64
# ----------------------------------------
# Y    218340
# N     89171
# Name: FLAG_DOCUMENT_3, dtype: int64
# ----------------------------------------
# N    307139
# Y       372
# Name: FLAG_DOCUMENT_15, dtype: int64
# ...

# %%
df[to_convert].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 307511 entries, 100002 to 456255
# Data columns (total 10 columns):
# FLAG_MOBIL          307511 non-null object
# FLAG_EMP_PHONE      307511 non-null object
# FLAG_WORK_PHONE     307511 non-null object
# FLAG_CONT_MOBILE    307511 non-null object
# FLAG_PHONE          307511 non-null object
# FLAG_EMAIL          307511 non-null object
# FLAG_DOCUMENT_8     307511 non-null object
# FLAG_DOCUMENT_3     307511 non-null object
# FLAG_DOCUMENT_15    307511 non-null object
# FLAG_DOCUMENT_19    307511 non-null object
# dtypes: object(10)
# memory usage: 25.8+ MB

# %% [markdown]
# # Analisando Missing Values - NaN

# %%
nulls_sum = df[missing].isnull().sum().sort_values()

# %%
nulls_sum
# Out:
# CNT_FAM_MEMBERS                  2
# AMT_ANNUITY                     12
# AMT_GOODS_PRICE                278
# DEF_30_CNT_SOCIAL_CIRCLE      1021
# NAME_TYPE_SUITE               1292
# OCCUPATION_TYPE              96391
# EMERGENCYSTATE_MODE         145755
# LIVINGAREA_MEDI             154350
# OWN_CAR_AGE                 202929
# FLOORSMIN_AVG               208642
# dtype: int64

# %%
with plt.style.context(plot_style):
    plt.figure()
    plt.title("Quantidade de Missing Values", fontsize = 25)
    nulls_sum.plot(kind = 'bar',    figsize = (10,5), )
    plt.show()

# %% [markdown]
# ### Representatividade dos Missing Values nas amostras

# %%
total_dados = df[missing].shape[0]
total_dados
# Out:
# 307511

# %%
for col, value in nulls_sum.items():
    str1 = (col + 30 * ' ')[:25]
    str2 = (7 * ' ' + str(value))[-7:]
    str3 = (7 * ' ' + str(format(round(value / total_dados * 100, 2), '.2f')) + '%')[-7:]
    print (str1 + ' -> ' + str2 + ' = ' + str3)
# Out:
# CNT_FAM_MEMBERS           ->       2 =   0.00%
# AMT_ANNUITY               ->      12 =   0.00%
# AMT_GOODS_PRICE           ->     278 =   0.09%
# DEF_30_CNT_SOCIAL_CIRCLE  ->    1021 =   0.33%
# NAME_TYPE_SUITE           ->    1292 =   0.42%
# OCCUPATION_TYPE           ->   96391 =  31.35%
# EMERGENCYSTATE_MODE       ->  145755 =  47.40%
# LIVINGAREA_MEDI           ->  154350 =  50.19%
# OWN_CAR_AGE               ->  202929 =  65.99%
# FLOORSMIN_AVG             ->  208642 =  67.85%

# %% [markdown]
# **Vemos que para algumas variáveis os Missing Values possuem pouca representatividade**
# ```
# CNT_FAM_MEMBERS           ->       2 =   0.00%
# AMT_ANNUITY               ->      12 =   0.00%
# AMT_GOODS_PRICE           ->     278 =   0.09%
# DEF_30_CNT_SOCIAL_CIRCLE  ->    1021 =   0.33%
# NAME_TYPE_SUITE           ->    1292 =   0.42%
# ```

# %% [markdown]
# **E para outras a sua representatividade sobre o Total é elevada**
#
# ```
# OCCUPATION_TYPE           ->   96391 =  31.35%
# EMERGENCYSTATE_MODE       ->  145755 =  47.40%
# LIVINGAREA_MEDI           ->  154350 =  50.19%
# OWN_CAR_AGE               ->  202929 =  65.99%
# FLOORSMIN_AVG             ->  208642 =  67.85%
# ```

# %% [markdown]
# **Para as primeiras variáveis que possuem menos de 1% de Missing Values vou excluí-los da amostra**

# %% [markdown]
# **Para as demais vou tratá-los de outra forma**

# %%
nan_excluir = [
    'CNT_FAM_MEMBERS',
    'AMT_ANNUITY',
    'AMT_GOODS_PRICE',
    'DEF_30_CNT_SOCIAL_CIRCLE',
    'NAME_TYPE_SUITE',
]

# %%
nan_excluir
# Out:
# ['CNT_FAM_MEMBERS',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'NAME_TYPE_SUITE']

# %%
nan_tratar =[
    'OCCUPATION_TYPE',
    'EMERGENCYSTATE_MODE',
    'LIVINGAREA_MEDI',
    'OWN_CAR_AGE',   
    'FLOORSMIN_AVG',
]

# %%
nan_tratar
# Out:
# ['OCCUPATION_TYPE',
#  'EMERGENCYSTATE_MODE',
#  'LIVINGAREA_MEDI',
#  'OWN_CAR_AGE',
#  'FLOORSMIN_AVG']

# %% [markdown]
# ## Tratamento Missing Values - Exclusão

# %%
df.dropna(subset = nan_excluir, inplace = True)

# %%
df[nan_excluir].isnull().sum().sort_values()
# Out:
# CNT_FAM_MEMBERS             0
# AMT_ANNUITY                 0
# AMT_GOODS_PRICE             0
# DEF_30_CNT_SOCIAL_CIRCLE    0
# NAME_TYPE_SUITE             0
# dtype: int64

# %% [markdown]
# ## Tratamento Missing Values - Alteração

# %% [markdown]
# #### OCCUPATION_TYPE (Tipo Categórico)

# %%
df['OCCUPATION_TYPE'].value_counts(dropna = False).sort_values()
# Out:
# IT staff                   512
# HR staff                   558
# Realty agents              744
# Secretaries               1294
# Waiters/barmen staff      1338
# Low-skill Laborers        2083
# Private service staff     2632
# Cleaning staff            4624
# Cooking staff             5912
# Security staff            6679
# Medicine staff            8483
# Accountants               9722
# High skill tech staff    11279
# Drivers                  18484
# Managers                 21139
# Core staff               27314
# Sales staff              31876
# Laborers                 54832
# NaN                      95681
# Name: OCCUPATION_TYPE, dtype: int64

# %% [markdown]
# **Vou considerar os NaNs como não informado e mantê-los 'XNA'**

# %%
df['OCCUPATION_TYPE'].fillna('XNA', inplace=True)

# %%
df['OCCUPATION_TYPE'].value_counts(dropna = False).sort_values()
# Out:
# IT staff                   512
# HR staff                   558
# Realty agents              744
# Secretaries               1294
# Waiters/barmen staff      1338
# Low-skill Laborers        2083
# Private service staff     2632
# Cleaning staff            4624
# Cooking staff             5912
# Security staff            6679
# Medicine staff            8483
# Accountants               9722
# High skill tech staff    11279
# Drivers                  18484
# Managers                 21139
# Core staff               27314
# Sales staff              31876
# Laborers                 54832
# XNA                      95681
# Name: OCCUPATION_TYPE, dtype: int64

# %% [markdown]
# #### EMERGENCYSTATE_MODE (Tipo Categórico)

# %%
df['EMERGENCYSTATE_MODE'].value_counts(dropna = False).sort_values()
# Out:
# Yes      2317
# NaN    144816
# No     158053
# Name: EMERGENCYSTATE_MODE, dtype: int64

# %% [markdown]
# **Como a quantidade de NaN é muito alta, também vou considerá-la como não informado 'XNA'**

# %%
df['EMERGENCYSTATE_MODE'].fillna('XNA', inplace=True)

# %%
df['EMERGENCYSTATE_MODE'].value_counts(dropna = False).sort_values()
# Out:
# Yes      2317
# XNA    144816
# No     158053
# Name: EMERGENCYSTATE_MODE, dtype: int64

# %% [markdown]
# ## Tratamentos dos Missing Values - NÃO CATEGÓRICOS

# %% [markdown]
# #### LIVINGAREA_MEDI (Tipo Não Categórico)

# %%
df['LIVINGAREA_MEDI'].value_counts(dropna = False).sort_values().head(10)
# Out:
# 438.400m    1
# 265.000m    1
# 481.200m    1
# 642.400m    1
# 371.400m    1
# 450.700m    1
# 670.800m    1
# 476.700m    1
# 627.800m    1
# 278.700m    1
# Name: LIVINGAREA_MEDI, dtype: int64

# %% [markdown]
# **Vou colocar a área = -1 para identificar que trata-se de um valor não informado**
# **A quantidade de NaN na amostra é muito elevada para considerar pela média ou pelos vizinhos**

# %%
df['LIVINGAREA_MEDI'] = df['LIVINGAREA_MEDI'].apply(lambda x: round(x, 4) if pd.notna(x) else -1 )

# %%
df['LIVINGAREA_MEDI'].describe()
# Out:
# count    305.186k
# mean    -448.488m
# std      559.850m
# min        -1.000
# 25%        -1.000
# 50%        -1.000
# 75%       74.400m
# max         1.000
# Name: LIVINGAREA_MEDI, dtype: float64

# %% [markdown]
# #### OWN_CAR_AGE (Tipo Não Categórico)

# %%
df['OWN_CAR_AGE'].value_counts(dropna = False).sort_values().head(10)
# Out:
# 50.000    1
# 48.000    1
# 69.000    1
# 56.000    1
# 47.000    1
# 52.000    1
# 57.000    1
# 63.000    2
# 91.000    2
# 51.000    3
# Name: OWN_CAR_AGE, dtype: int64

# %%
df['OWN_CAR_AGE'] = df['LIVINGAREA_MEDI'].apply(lambda x: round(x, 4) if pd.notna(x) else -1 )

# %%
df['OWN_CAR_AGE'].describe()
# Out:
# count    305.186k
# mean    -448.488m
# std      559.850m
# min        -1.000
# 25%        -1.000
# 50%        -1.000
# 75%       74.400m
# max         1.000
# Name: OWN_CAR_AGE, dtype: float64

# %% [markdown]
# #### FLOORSMIN_AVG (Tipo Não Categórico)

# %%
df['FLOORSMIN_AVG'].value_counts(dropna = False).sort_values().head(10)
# Out:
# 572.900m    1
# 13.800m     1
# 847.100m    1
# 203.300m    1
# 633.300m    1
# 170.800m    1
# 100.000m    1
# 47.900m     1
# 600.000m    1
# 317.500m    1
# Name: FLOORSMIN_AVG, dtype: int64

# %%
df['FLOORSMIN_AVG'] = df['LIVINGAREA_MEDI'].apply(lambda x: round(x, 4) if pd.notna(x) else -1 )

# %%
df['FLOORSMIN_AVG'].describe()
# Out:
# count    305.186k
# mean    -448.488m
# std      559.850m
# min        -1.000
# 25%        -1.000
# 50%        -1.000
# 75%       74.400m
# max         1.000
# Name: FLOORSMIN_AVG, dtype: float64

# %% [markdown]
# ## Resultado do tratamento dos Missing Values (NaN)

# %%
df[missing].isnull().sum().sort_values()
# Out:
# AMT_ANNUITY                 0
# AMT_GOODS_PRICE             0
# NAME_TYPE_SUITE             0
# OWN_CAR_AGE                 0
# OCCUPATION_TYPE             0
# CNT_FAM_MEMBERS             0
# DEF_30_CNT_SOCIAL_CIRCLE    0
# LIVINGAREA_MEDI             0
# EMERGENCYSTATE_MODE         0
# FLOORSMIN_AVG               0
# dtype: int64

# %% [markdown]
# ## Refresh da Separação das Colunas
#
#
# ## Atualizar porque algumas colunas foram convertidas em categóricas

# %%
# Colunas Categóricas:
categoricas = df.select_dtypes(exclude=['int', 'float']).columns

# %%
# Colunas Não Categóricas
nao_categoricas = df.select_dtypes(exclude=['object']).columns

# %% [markdown]
# # <font color='#b94646'> Gráficos </font>

# %% [markdown]
# ## Não Categóricas

# %%
# Não vou plotar as 2 primeiras colunas - Índice e o Target

side = 0
limit = 3

font = {'family': 'sans-serif',
        'color':  'black',
        'weight': 'normal',
        'size': 16,
        }

with plt.style.context(plot_style):
    
    for x in nao_categoricas[1:]:
        side += 1
        fsize = (12.0, 4.0)
        
        plt.subplots_adjust(left=-0.2)
        plt.subplot(1, limit, side)

        plt.title(x, fontsize = 18)
        #barcolor = 'steelblue'
        barcolor = '#4C72B0'
        
        # Plotando o gráfico
        df[x].sort_index().plot(kind = 'hist', figsize = fsize, facecolor=barcolor)
        
        if side == limit:
            side = 0
            plt.tight_layout()
            plt.show()

# %% [markdown]
# ## Categóricas

# %%
# Separando as variáveis por tamanho do gráfico a ser impresso
grafP = categoricas.drop(['OCCUPATION_TYPE','ORGANIZATION_TYPE'])
grafG = ['OCCUPATION_TYPE','ORGANIZATION_TYPE']

# %%
# Rotina para imprimir os gráficos
def imprime_categoricas(limit, colunas):
    side = 0

    font = {'family': 'sans-serif',
            'color':  'black',
            'weight': 'normal',
            'size': 16,
            }

    with plt.style.context(plot_style):
        for x in colunas:
            side += 1
            fsize = (15.0, 7.0)

            plt.subplots_adjust(left=-0.2)
            plt.subplot(1, limit, side)

            plt.title(x, fontsize = 18)
            plt.xticks(fontsize=12, rotation=90)

            if x in ['OCCUPATION_TYPE','ORGANIZATION_TYPE']:
                plt.subplot(1, 1, 1)
    #            fsize = (14.0, 7.0)

            df[x].value_counts().sort_index().plot(kind = 'bar', figsize = fsize)

            if side == limit:
                side = 0
                plt.tight_layout()
                plt.show()

# %%
imprime_categoricas(3, grafP)

# %%
imprime_categoricas(1, grafG)

# %% [markdown]
# **OBS.: EMERGENCYSTATE_MODE** está com domínios Yes / No, vou trocar para Y/N para padronizar com os outros

# %%
df['EMERGENCYSTATE_MODE'].replace({'Yes' : 'Y', 'No': 'N'}, inplace=True)

# %%
df['EMERGENCYSTATE_MODE'].value_counts()
# Out:
# N      158053
# XNA    144816
# Y        2317
# Name: EMERGENCYSTATE_MODE, dtype: int64

# %% [markdown]
# # Análise Bivariada

# %% [markdown]
# ## Correlação Numérica

# %%
all_corr = df[nao_categoricas[1:]].corr()

# %%
all_corr = all_corr.apply(lambda x: round(x, 10))

# %%
nao_categoricas[1:].value_counts().sum()
# Out:
# 16

# %%
# Define the plot
fig, ax = plt.subplots(figsize=(16,12))

# Add title to the Head Map
title = "Correlação Entre as Variáveis"

# Set the font size and the distance of the title from the plot
plt.title(title, fontsize=22)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12, rotation=0)

ax.title.set_position([0.5, 1.02])

# Generate a mask for the upper triangle
mask = np.zeros_like(all_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True


sns.heatmap(all_corr, annot=True, fmt='.2f', mask=mask, cmap='viridis', linewidths=0.5, ax=ax, cbar_kws={"shrink": .7} )
plt.show()

# Cores:
# - cmap='viridis'
# - cmap='RdYlGn'
# - robust=True

# %% [markdown]
# # <font color='#b94646'> Insigths sobre a correlação: </font>
#
#
# * As variáveis <font color='#b94646'> **FLOORSMIN_AVG X OWN_CAR_AGE**, **FLOORSMIN_AVG X LIVINGAREA_MEDI** e **LIVINGAREA_MEDI X OWN_CAR_AGE** </font> possuem Covariância muito elevada = 1.00.
# > Todas são variáveis que estavam com elevado valor de NaN e foram tratadas.
# > Verificar se o modelo melhora ao retirá-las.
#
# * <font color='#b94646'> **AMT_GOODS_PRICE X AMT_CREDIT X AMT_ANNUITY** </font> quanto maior o valor dos bens que o cliente possui, maior o valor do empréstimo a ser dado e o AMT_ANNUITY deve compor o valor do empréstimo.
#
#
# * <font color='#b94646'> **CNT_FAM_MEMBERS X CNT_CHILDREN** </font> possuem correlação elevada, mas a variável CNT_CHILDREN (Quantidade de filhos) compõe a variável CNT_FAM_MEMBERS (Quantidade de familiares)
#
#
# * Existe forte correlação negativa entre <font color='#b94646'>  **REGION_RATING_CLIENT_W_CITY X REGION_POPULATION_RELATIVE** </font>
#
#
# * Também existe forte correlação negativa entre <font color='#b94646'>  **DAYS_BIRTH X DAYS_EMPLOYED** </font>

# %% [markdown]
# ## Aplicando correlação entre as variáveis

# %%
y = nao_categoricas[1]
x = nao_categoricas[2]
for a in nao_categoricas[3:]:
    x += ' + ' + a

print ('Expressão: ')
print (y + ' ~ ' + x)

    
results = smf.ols(y + '~' + x, data=df).fit()
# Out:
# Expressão:
# CNT_CHILDREN ~ AMT_INCOME_TOTAL + AMT_CREDIT + AMT_ANNUITY + AMT_GOODS_PRICE + REGION_POPULATION_RELATIVE + DAYS_BIRTH + DAYS_EMPLOYED + DAYS_REGISTRATION + DAYS_ID_PUBLISH + OWN_CAR_AGE + CNT_FAM_MEMBERS + DEF_30_CNT_SOCIAL_CIRCLE + LIVINGAREA_MEDI + REGION_RATING_CLIENT_W_CITY + FLOORSMIN_AVG

# %%
# Imprimindo o resultado da Regressão:
print(80 * '-')
print(results.summary())
# Out:
# --------------------------------------------------------------------------------
#                             OLS Regression Results
# ...
# Dep. Variable:           CNT_CHILDREN   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.786
# Method:                 Least Squares   F-statistic:                 8.610e+04
# Date:                Thu, 09 Aug 2018   Prob (F-statistic):               0.00
# Time:                        01:15:20   Log-Likelihood:                -98641.
# No. Observations:              305186   AIC:                         1.973e+05
# Df Residuals:                  305172   BIC:                         1.975e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# ...

# %%
modelo = sm.OLS(df[nao_categoricas[2]], df[nao_categoricas[3:]])
results = modelo.fit()
print(results.params)
# Out:
# AMT_CREDIT                     -25.789m
# AMT_ANNUITY                       2.872
# AMT_GOODS_PRICE                 40.114m
# REGION_POPULATION_RELATIVE       1.144M
# DAYS_BIRTH                       -2.804
# DAYS_EMPLOYED                 -115.649m
# DAYS_REGISTRATION              890.592m
# DAYS_ID_PUBLISH                  -2.398
# OWN_CAR_AGE                      3.602k
# CNT_FAM_MEMBERS                  5.505k
# DEF_30_CNT_SOCIAL_CIRCLE        -2.665k
# LIVINGAREA_MEDI                  3.602k
# REGION_RATING_CLIENT_W_CITY      5.748k
# FLOORSMIN_AVG                    3.602k
# dtype: float64

# %% [markdown]
# ## Categórica

# %%
# Fazer o cruzamento das variáveis categóricas 2 a 2
catx  = categoricas
caty  = categoricas
cross = dict()

# %%
#for x in catx:
#    for y in caty:
#        if x < y:
#            crossX = pd.crosstab(df[x], df[y])
#            cross[x + ' X ' + y] = crossX

# %%
#y = 1
for x in categoricas:
    crossX = pd.crosstab(df['TARGET'], df[x])
    cross[x] = crossX
    #y +=1

# %%
for key, value in cross.items():
    #print(key)
    print(80 * '-')
    print(value)
    print()
    print()
    print()
# Out:
# --------------------------------------------------------------------------------
# NAME_CONTRACT_TYPE  Cash loans  Revolving loans
# TARGET
# 0                       254039            26428
# 1                        23173             1546
#
#
#
# --------------------------------------------------------------------------------
# CODE_GENDER       F      M  XNA
# TARGET
# 0            186878  93585    4
# 1             14102  10617    0
#
#
#
# --------------------------------------------------------------------------------
# FLAG_OWN_CAR       N      Y
# TARGET
# 0             184207  96260
# 1              17172   7547
#
#
#
# --------------------------------------------------------------------------------
# FLAG_OWN_REALTY      N       Y
# TARGET
# 0                85286  195181
# 1                 7798   16921
#
#
#
# --------------------------------------------------------------------------------
# NAME_TYPE_SUITE  Children  Family  Group of people  Other_A  Other_B  \
# TARGET
# ...

# %%
# Rotina para imprimir os gráficos
def heatmap_categoricas(limit, cross):
    side = 0

    font = {'family': 'sans-serif',
            'color':  'black',
            'weight': 'normal',
            'size': 16,
            }

    with plt.style.context(plot_style):
        for key, value in cross.items():
            side += 1
            fsize = (15.0, 7.0)

            plt.subplots_adjust(left=-0.2)
            plt.subplot(1, limit, side)

            plt.title(key, fontsize = 10)
            plt.xticks(fontsize=12, rotation=90)

   
            #df[x].value_counts().sort_index().plot(kind = 'bar', figsize = fsize)
            sns.heatmap(value, annot=True, fmt='d', cmap="YlGnBu", linewidths=0.03, ax=ax, )

            if side == limit:
                side = 0
                plt.tight_layout()
                plt.show()

# %%
for key, value in cross.items():
    
    fsize=(8,4)
    if key == "ORGANIZATION_TYPE":
        fsize=(20,5)

    # Define the plot
    fig, ax = plt.subplots(figsize=fsize)


    # Add title to the Head Map
    title = key

    # Set the font size and the distance of the title from the plot
    plt.title(title, fontsize=16)
    ttl = ax.title
    ttl.set_position([0.5, 1.05])

    # Hide ticks for X & Y axis
    ax.set_xticks([])
    ax.set_yticks([])

    # Remove the axes
    #ax.axis('off')

    sns.heatmap(value, annot=False, fmt='d', cmap="YlGnBu", linewidths=0.03, ax=ax, )
    #cmap='viridis'
    #cmap='RdYlGn'
    #cmap='YlGnBu'
    #robust=True
    
    plt.show()

# %% [markdown]
# # Categorias vs Numéricas

# %%
categoricas
# Out:
# Index(['NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY',
#        'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE',
#        'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE', 'FLAG_MOBIL',
#        'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'OCCUPATION_TYPE', 'FLAG_DOCUMENT_8', 'FLAG_DOCUMENT_3',
#        'FLAG_DOCUMENT_15', 'EMERGENCYSTATE_MODE', 'FLAG_DOCUMENT_19',
#        'ORGANIZATION_TYPE'],
#       dtype='object')

# %%
nao_categoricas
# Out:
# Index(['TARGET', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT',
#        'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'REGION_POPULATION_RELATIVE',
#        'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH',
#        'OWN_CAR_AGE', 'CNT_FAM_MEMBERS', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'LIVINGAREA_MEDI', 'REGION_RATING_CLIENT_W_CITY', 'FLOORSMIN_AVG'],
#       dtype='object')

# %%
#sns.boxplot(data = df, x = 'NAME_CONTRACT_TYPE', y = 'CNT_CHILDREN')

# %% [markdown]
# # <font color='#b94646'> Preparando os dados para Machine Learn </font>

# %%
mlBkp = df.copy(deep=True)

# %%
# Fazer o FIT dos dados

le = LabelEncoder()

# %%
# Vou transformar a base toda, só vou deixar os campos indice e Target de fora
for x in df.columns[1:]:
    df[x] = le.fit_transform(df[x])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305186 entries, 100002 to 456255
# Data columns (total 39 columns):
# TARGET                         305186 non-null int64
# NAME_CONTRACT_TYPE             305186 non-null int64
# CODE_GENDER                    305186 non-null int64
# FLAG_OWN_CAR                   305186 non-null int64
# FLAG_OWN_REALTY                305186 non-null int64
# CNT_CHILDREN                   305186 non-null int64
# AMT_INCOME_TOTAL               305186 non-null int64
# AMT_CREDIT                     305186 non-null int64
# AMT_ANNUITY                    305186 non-null int64
# AMT_GOODS_PRICE                305186 non-null int64
# NAME_TYPE_SUITE                305186 non-null int64
# NAME_INCOME_TYPE               305186 non-null int64
# NAME_EDUCATION_TYPE            305186 non-null int64
# NAME_FAMILY_STATUS             305186 non-null int64
# NAME_HOUSING_TYPE              305186 non-null int64
# ...

# %%
# Dividindo entre Alvo e Dados

X = df.drop(['TARGET'], axis = 1)
Y = df['TARGET']

# %% [markdown]
# ## Dividindo as amostras

# %%
# ->  from sklearn.model_selection import train_test_split

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X,Y, test_size=0.33, random_state=42)

# %%
print(Xtrain.shape)
print(Xtest.shape)
print(Ytrain.shape)
print(Ytest.shape)
# Out:
# (204474, 38)
# (100712, 38)
# (204474,)
# (100712,)

# %% [markdown]
# ## Preparando Machine Learn

# %%
# Criando o Classificador - RandomForest
rf = RandomForestClassifier()

# %%
rf.fit(Xtrain, Ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## <font color='#b94646'> Resultado 1 </font>

# %%
accuracy_score(Ytest, rf.predict(Xtest))
# Out:
# 0.9173484788307252

# %% [markdown]
# ## E se tirar algumas variáveis?
#
# ### Vou retirar variáveis 1 a 1 pelo maior PValue da regressão:
#
# ```
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       0.1151      0.004     27.018      0.000       0.107       0.123
# CNT_CHILDREN                    0.0070      0.001      4.751      0.000       0.004       0.010
# AMT_INCOME_TOTAL             3.104e-09   2.11e-09      1.473      0.141   -1.03e-09    7.23e-09 <== 3.o
# AMT_CREDIT                   2.224e-07    7.6e-09     29.275      0.000    2.07e-07    2.37e-07
# AMT_ANNUITY                  7.525e-07   5.43e-08     13.865      0.000    6.46e-07    8.59e-07
# AMT_GOODS_PRICE             -2.809e-07   8.36e-09    -33.605      0.000   -2.97e-07   -2.65e-07
# REGION_POPULATION_RELATIVE     -0.0178      0.042     -0.423      0.672      -0.100       0.064 <== 1.o
# DAYS_BIRTH                   4.168e-06   1.55e-07     26.948      0.000    3.86e-06    4.47e-06
# DAYS_EMPLOYED                6.334e-09   4.51e-09      1.405      0.160    -2.5e-09    1.52e-08 <== 2.o
# DAYS_REGISTRATION            1.012e-06   1.49e-07      6.801      0.000     7.2e-07     1.3e-06
# DAYS_ID_PUBLISH              5.578e-06   3.44e-07     16.219      0.000     4.9e-06    6.25e-06
# OWN_CAR_AGE                    -0.0046      0.000    -15.362      0.000      -0.005      -0.004
# CNT_FAM_MEMBERS                -0.0091      0.001     -7.936      0.000      -0.011      -0.007
# DEF_30_CNT_SOCIAL_CIRCLE        0.0185      0.001     16.856      0.000       0.016       0.021
# LIVINGAREA_MEDI                -0.0046      0.000    -15.362      0.000      -0.005      -0.004
# REGION_RATING_CLIENT_W_CITY     0.0292      0.001     24.966      0.000       0.027       0.031
# FLOORSMIN_AVG                  -0.0046      0.000    -15.362      0.000      -0.005      -0.004
# ```

# %%
X1train = Xtrain.drop(['REGION_POPULATION_RELATIVE'], axis = 1)
X1test  = Xtest.drop(['REGION_POPULATION_RELATIVE'], axis = 1)

# %%
rf.fit(X1train, Ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## <font color='#b94646'> Resultado 2 - melhorou um pouco </font>

# %%
accuracy_score(Ytest, rf.predict(X1test))
# Out:
# 0.917199539280324

# %% [markdown]
# ### Excluir mais uma variável

# %%
X2train = X1train.drop(['DAYS_EMPLOYED'], axis = 1)
X2test  = X1test.drop(['DAYS_EMPLOYED'], axis = 1)

# %%
rf.fit(X2train, Ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## <font color='#b94646'> Resultado 3 - praticamente igual </font>

# %%
accuracy_score(Ytest, rf.predict(X2test))
# Out:
# 0.9171101755500835

# %% [markdown]
# ### Excluir mais uma variável

# %%
X3train = X1train.drop(['AMT_INCOME_TOTAL'], axis = 1)
X3test  = X1test.drop(['AMT_INCOME_TOTAL'], axis = 1)

# %%
rf.fit(X3train, Ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## <font color='#b94646'> Resultado 4 - praticamente o mesmo </font>

# %%
accuracy_score(Ytest, rf.predict(X3test))
# Out:
# 0.9169910239097625

# %%
# ['FLOORSMIN_AVG', 'OWN_CAR_AGE', 'LIVINGAREA_MEDI']

# %% [markdown]
# ### Excluindo as 3 variáveis juntas

# %%
X4train = X1train.drop(['FLOORSMIN_AVG', 'OWN_CAR_AGE', 'LIVINGAREA_MEDI'], axis = 1)
X4test  = X1test.drop(['FLOORSMIN_AVG', 'OWN_CAR_AGE', 'LIVINGAREA_MEDI'], axis = 1)

# %%
rf.fit(X4train, Ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# ## <font color='#b94646'> Resultado 5 - Resultado praticamente o mesmo </font>

# %%
accuracy_score(Ytest, rf.predict(X4test))
# Out:
# 0.9172789737072047

# %% [markdown]
# # <font color='#b94646'> Agregando dados - Merge </font>

# %%
df1 = mlBkp.copy(deep=False)

# %%
#df1.set_index('SK_ID_CURR', inplace = True);

# %%
df1.head()
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
#
#            FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR
# 100002                   Y             0          202.500k    406.598k
# 100003                   N             0          270.000k      1.294M
# 100004                   Y             0           67.500k    135.000k
# 100006                   Y             0          135.000k    312.682k
# 100007                   Y             0          121.500k    513.000k
#
#             AMT_ANNUITY  AMT_GOODS_PRICE           ...            \
# SK_ID_CURR                                         ...
# ...

# %% [markdown]
# ## Carregando a base: bureau

# %%
bureau = pd.read_csv('./data/bureau.csv')

# %%
bureau.set_index('SK_ID_CURR', inplace = True);

# %%
bureau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1716428 entries, 215354 to 246829
# Data columns (total 16 columns):
# SK_ID_BUREAU              int64
# CREDIT_ACTIVE             object
# CREDIT_CURRENCY           object
# DAYS_CREDIT               int64
# CREDIT_DAY_OVERDUE        int64
# DAYS_CREDIT_ENDDATE       float64
# DAYS_ENDDATE_FACT         float64
# AMT_CREDIT_MAX_OVERDUE    float64
# CNT_CREDIT_PROLONG        int64
# AMT_CREDIT_SUM            float64
# AMT_CREDIT_SUM_DEBT       float64
# AMT_CREDIT_SUM_LIMIT      float64
# AMT_CREDIT_SUM_OVERDUE    float64
# CREDIT_TYPE               object
# DAYS_CREDIT_UPDATE        int64
# AMT_ANNUITY               float64
# dtypes: float64(8), int64(5), object(3)
# memory usage: 222.6+ MB

# %%
bureau.head()
# Out:
#             SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# SK_ID_CURR
# 215354           5714462        Closed      currency 1         -497
# 215354           5714463        Active      currency 1         -208
# 215354           5714464        Active      currency 1         -203
# 215354           5714465        Active      currency 1         -203
# 215354           5714466        Active      currency 1         -629
#
#             CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# SK_ID_CURR
# 215354                       0             -153.000           -153.000
# 215354                       0               1.075k                NaN
# 215354                       0              528.000                NaN
# 215354                       0                  NaN                NaN
# 215354                       0               1.197k                NaN
#
#             AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# SK_ID_CURR
# ...

# %%
df3 = pd.merge(df1, bureau, how='left', on='SK_ID_CURR')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499345 entries, 100002 to 456255
# Data columns (total 55 columns):
# TARGET                         1499345 non-null int64
# NAME_CONTRACT_TYPE             1499345 non-null object
# CODE_GENDER                    1499345 non-null object
# FLAG_OWN_CAR                   1499345 non-null object
# FLAG_OWN_REALTY                1499345 non-null object
# CNT_CHILDREN                   1499345 non-null int64
# AMT_INCOME_TOTAL               1499345 non-null float64
# AMT_CREDIT                     1499345 non-null float64
# AMT_ANNUITY_x                  1499345 non-null float64
# AMT_GOODS_PRICE                1499345 non-null float64
# NAME_TYPE_SUITE                1499345 non-null object
# NAME_INCOME_TYPE               1499345 non-null object
# NAME_EDUCATION_TYPE            1499345 non-null object
# NAME_FAMILY_STATUS             1499345 non-null object
# NAME_HOUSING_TYPE              1499345 non-null object
# ...

# %% [markdown]
# # <font color='#b94646'> Bureau parece ser uma boa base para se trabalhar </font>

# %% [markdown]
# ## Vou aplicar Machine Learn sobre a Base Principal + Bureau para ver o resultado

# %%
# Colunas com Missing Values
df3_miss = df3.columns[df3.isnull().any()]

# %%
df3_miss
# Out:
# Index(['SK_ID_BUREAU', 'CREDIT_ACTIVE', 'CREDIT_CURRENCY', 'DAYS_CREDIT',
#        'CREDIT_DAY_OVERDUE', 'DAYS_CREDIT_ENDDATE', 'DAYS_ENDDATE_FACT',
#        'AMT_CREDIT_MAX_OVERDUE', 'CNT_CREDIT_PROLONG', 'AMT_CREDIT_SUM',
#        'AMT_CREDIT_SUM_DEBT', 'AMT_CREDIT_SUM_LIMIT', 'AMT_CREDIT_SUM_OVERDUE',
#        'CREDIT_TYPE', 'DAYS_CREDIT_UPDATE', 'AMT_ANNUITY_y'],
#       dtype='object')

# %% [markdown]
# ## Vou dividir as variáveis em Categoricas e Numéricas:

# %%
# Colunas Categóricas:
df3_miss_cat = df3[df3_miss].select_dtypes(exclude=['int', 'float']).columns

# %%
df3_miss_cat
# Out:
# Index(['CREDIT_ACTIVE', 'CREDIT_CURRENCY', 'CREDIT_TYPE'], dtype='object')

# %%
# Verificando as variáveis Categóricas:
for x in df3_miss_cat:
    print(x)
    print(df3[x].value_counts(dropna=False))
    print(80 * '-'+'\n\n')
# Out:
# CREDIT_ACTIVE
# Closed      911812
# Active      538184
# NaN          43707
# Sold          5622
# Bad debt        20
# Name: CREDIT_ACTIVE, dtype: int64
# --------------------------------------------------------------------------------
#
#
# CREDIT_CURRENCY
# currency 1    1454433
# NaN             43707
# currency 2       1049
# currency 3        147
# currency 4          9
# Name: CREDIT_CURRENCY, dtype: int64
# --------------------------------------------------------------------------------
#
#
# CREDIT_TYPE
# Consumer credit                                 1062987
# Credit card                                      341298
# NaN                                               43707
# Car loan                                          23502
# Mortgage                                          15434
# Microloan                                          8949
# Loan for business development                      1716
# Another type of loan                                840
# ...

# %%
# Colunas Não Categóricas
df3_miss_num = df3[df3_miss].select_dtypes(exclude=['object']).columns

# %%
df3_miss_num
# Out:
# Index(['SK_ID_BUREAU', 'DAYS_CREDIT', 'CREDIT_DAY_OVERDUE',
#        'DAYS_CREDIT_ENDDATE', 'DAYS_ENDDATE_FACT', 'AMT_CREDIT_MAX_OVERDUE',
#        'CNT_CREDIT_PROLONG', 'AMT_CREDIT_SUM', 'AMT_CREDIT_SUM_DEBT',
#        'AMT_CREDIT_SUM_LIMIT', 'AMT_CREDIT_SUM_OVERDUE', 'DAYS_CREDIT_UPDATE',
#        'AMT_ANNUITY_y'],
#       dtype='object')

# %%
# Verificando as variáveis Numéricas
for x in df3_miss_num:
    print('          ' + x)
    print(df3[x].head(5))
    print()
    print('Min - ' + str(df3[x].describe().min()))
    print('Max - ' + str(df3[x].describe().max()))
    print(80 * '-'+'\n\n')
# Out:
#           SK_ID_BUREAU
# SK_ID_CURR
# 100002    6.159M
# 100002    6.159M
# 100002    6.159M
# 100002    6.159M
# 100002    6.159M
# Name: SK_ID_BUREAU, dtype: float64
#
# Min - 537302.4714
# Max - 6843457.0
# --------------------------------------------------------------------------------
#
#
#           DAYS_CREDIT
# SK_ID_CURR
# 100002    -1.125k
# 100002   -476.000
# 100002    -1.437k
# 100002    -1.121k
# 100002   -645.000
# Name: DAYS_CREDIT, dtype: float64
#
# Min - -2922.0
# Max - 1455638.0
# --------------------------------------------------------------------------------
#
#
#           CREDIT_DAY_OVERDUE
# SK_ID_CURR
# 100002    0.000
# 100002    0.000
# 100002    0.000
# 100002    0.000
# 100002    0.000
# Name: CREDIT_DAY_OVERDUE, dtype: float64
#
# Min - 0.0
# Max - 1455638.0
# --------------------------------------------------------------------------------
#
#
#           DAYS_CREDIT_ENDDATE
# SK_ID_CURR
# 100002    -1.038k
# 100002        NaN
# 100002    -1.072k
# ...

# %% [markdown]
# ## As variáveis categóricas vou substituir po XNA (não informado)

# %%
for x in df3_miss_cat:
    df3[x].fillna('XNA', inplace=True)

# %% [markdown]
# **Verificando se sobraram Missing Values nas Colunas Categóricas**

# %%
# Colunas com Missing Values
df3[df3_miss_cat].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499345 entries, 100002 to 456255
# Data columns (total 3 columns):
# CREDIT_ACTIVE      1499345 non-null object
# CREDIT_CURRENCY    1499345 non-null object
# CREDIT_TYPE        1499345 non-null object
# dtypes: object(3)
# memory usage: 45.8+ MB

# %% [markdown]
# ## As variáveis numéricas, precisam ser tratadas caso a caso:

# %% [markdown]
# ```
# -------------------------------------------------------------------------------------------------
#  CAMPO                      AÇÃO
# -------------------------------------------------------------------------------------------------
#  SK_ID_BUREAU               Trocar para 0
#  DAYS_CREDIT                Excluir
#  CREDIT_DAY_OVERDUE         Valores são positivos, colocar como -1
#  DAYS_CREDIT_ENDDATE        Excluir
#  DAYS_ENDDATE_FACT          Excluir
#  AMT_CREDIT_MAX_OVERDUE     Valores positivos, colocar -1
#  CNT_CREDIT_PROLONG         Valores de 0 para positivo, colocar -1
#  AMT_CREDIT_SUM             Valores de 0 para positivo, colocar -1
#  AMT_CREDIT_SUM_DEBT        Valores negativos e positivos, colocar 0? (verificar se excluir fica melhor)
#  AMT_CREDIT_SUM_LIMIT       Valores negativos e positivos, colocar 0? (verificar se excluir fica melhor)
#  AMT_CREDIT_SUM_OVERDUE     Valores 0 e +, colocar -1
#  DAYS_CREDIT_UPDATE         Excluir
#  AMT_ANNUITY_y              Valores 0 e +, colocar -1
# ```

# %% [markdown]
# ### Excluir Campos

# %%
df3 = df3.drop(['DAYS_CREDIT', 'DAYS_CREDIT_ENDDATE', 'DAYS_ENDDATE_FACT', 'DAYS_CREDIT_UPDATE', ], axis = 1)

# %% [markdown]
# ### Alterar Campos

# %%
df3['SK_ID_BUREAU'].fillna(0, inplace=True)

# %%
df3['CREDIT_DAY_OVERDUE'].fillna(-1, inplace=True)

# %%
df3['AMT_CREDIT_MAX_OVERDUE'].fillna(-1, inplace=True)

# %%
df3['CNT_CREDIT_PROLONG'].fillna(-1, inplace=True)

# %%
df3['AMT_CREDIT_SUM'].fillna(-1, inplace=True)

# %%
# Verificar se seria melhor excluir a coluna
df3['AMT_CREDIT_SUM_DEBT'].fillna(0, inplace=True)

# %%
# Verificar se seria melhor excluir a coluna
df3['AMT_CREDIT_SUM_LIMIT'].fillna(0, inplace=True)

# %%
df3['AMT_CREDIT_SUM_OVERDUE'].fillna(-1, inplace=True)

# %%
df3['AMT_ANNUITY_y'].fillna(-1, inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499345 entries, 100002 to 456255
# Data columns (total 51 columns):
# TARGET                         1499345 non-null int64
# NAME_CONTRACT_TYPE             1499345 non-null object
# CODE_GENDER                    1499345 non-null object
# FLAG_OWN_CAR                   1499345 non-null object
# FLAG_OWN_REALTY                1499345 non-null object
# CNT_CHILDREN                   1499345 non-null int64
# AMT_INCOME_TOTAL               1499345 non-null float64
# AMT_CREDIT                     1499345 non-null float64
# AMT_ANNUITY_x                  1499345 non-null float64
# AMT_GOODS_PRICE                1499345 non-null float64
# NAME_TYPE_SUITE                1499345 non-null object
# NAME_INCOME_TYPE               1499345 non-null object
# NAME_EDUCATION_TYPE            1499345 non-null object
# NAME_FAMILY_STATUS             1499345 non-null object
# NAME_HOUSING_TYPE              1499345 non-null object
# ...

# %% [markdown]
# ## Todas as colunas estão sem missing values

# %% [markdown]
# # Preparando base para Machine Learning

# %%
# Fazer o FIT dos dados
le = LabelEncoder()

# %%
# Vou transformar a base toda, só vou deixar os campos indice e Target de fora
for x in df3.columns[1:]:
    df3[x] = le.fit_transform(df3[x])

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499345 entries, 100002 to 456255
# Data columns (total 51 columns):
# TARGET                         1499345 non-null int64
# NAME_CONTRACT_TYPE             1499345 non-null int64
# CODE_GENDER                    1499345 non-null int64
# FLAG_OWN_CAR                   1499345 non-null int64
# FLAG_OWN_REALTY                1499345 non-null int64
# CNT_CHILDREN                   1499345 non-null int64
# AMT_INCOME_TOTAL               1499345 non-null int64
# AMT_CREDIT                     1499345 non-null int64
# AMT_ANNUITY_x                  1499345 non-null int64
# AMT_GOODS_PRICE                1499345 non-null int64
# NAME_TYPE_SUITE                1499345 non-null int64
# NAME_INCOME_TYPE               1499345 non-null int64
# NAME_EDUCATION_TYPE            1499345 non-null int64
# NAME_FAMILY_STATUS             1499345 non-null int64
# NAME_HOUSING_TYPE              1499345 non-null int64
# ...

# %% [markdown]
# ## Dividindo as amostras

# %%
# Dividindo entre Alvo e Dados
df3X = df3.drop(['TARGET'], axis = 1)
df3Y = df3['TARGET']

# %%
# ->  from sklearn.model_selection import train_test_split

df3Xtrain, df3Xtest, df3Ytrain, df3Ytest = train_test_split(df3X,df3Y, test_size=0.33, random_state=42)

# %%
print(df3Xtrain.shape)
print(df3Xtest.shape)
print(df3Ytrain.shape)
print(df3Ytest.shape)
# Out:
# (1004561, 50)
# (494784, 50)
# (1004561,)
# (494784,)

# %% [markdown]
# ## Preparando Machine Learn

# %%
# %%time

rf.fit(df3Xtrain, df3Ytrain)
# Out:
# CPU times: user 1min 29s, sys: 200 ms, total: 1min 29s
# Wall time: 1min 26s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %% [markdown]
# # <font color='#b94646'>RESULTADO FINAL !</font>

# %%
accuracy_score(df3Ytest, rf.predict(df3Xtest))
# Out:
# 0.9796133262191178

# %% [markdown]
# # <font color='#b94646'> CONCLUSÃO </font>

# %% [markdown]
# ## <font color='#b94646'> Ao se utilizar a base de Bureau, houve uma melhora significativa no modelo </font>
#
# ## <font color='#b94646'> Acurácia do modelo de </font> <font color='#ff0000'> 97,96% </font>
